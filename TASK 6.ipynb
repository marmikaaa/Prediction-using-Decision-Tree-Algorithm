# %% [markdown]
# # GRADUATE ROTATIONAL INTERNSHIP PROGRAM (GRIP)
# Data Science [#GRIPMARCH21]
# TASK 6: Prediction using Decision Tree Algorithm
# NAME: MARMIKA SAXENA

# %%
# importing all neccassary files
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the data
iris = pd.read_csv('E:\Downloads\Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
# checking the diamensions of data
iris.shape
# Out:
# (150, 6)

# %%
# checking the number of features in data
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# removing the inessential features
iris_1 = iris.drop(['Id'], axis= 1)

# Viewing the data
iris_1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Checking for the null values if any in given feature
print(iris_1.isnull().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Plotting a pair plot for more visualization
sns.pairplot(iris_1,hue='Species')
plt.show()

# %%
# Spliting the data into train and test
from sklearn.model_selection import train_test_split

# independent and dependent variable
X = iris_1.iloc[:, 0:-1]
y = iris_1.iloc[:, 4]

# %%
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
X_train.shape
# Out:
# (112, 4)

# %%
y_train.shape
# Out:
# (112,)

# %%
# Importing the model
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# Defining a variable for decision tree
iris_classifier = tree.DecisionTreeClassifier(criterion= 'entropy', random_state= 0)

# fitting the model
iris_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
# checking the mean accuracy of the model
iris_classifier.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %%
# Creating a test prediction variable and testing it
tree_test_predict = pd.DataFrame({"Actual": y_test, "Predicted": iris_classifier.predict(X_test)})

# %%
# Checking results
tree_test_predict.sample(n=10)
# Out:
#               Actual        Predicted
# 109   Iris-virginica   Iris-virginica
# 41       Iris-setosa      Iris-setosa
# 95   Iris-versicolor  Iris-versicolor
# 8        Iris-setosa      Iris-setosa
# 19       Iris-setosa      Iris-setosa
# 111   Iris-virginica   Iris-virginica
# 88   Iris-versicolor  Iris-versicolor
# 38       Iris-setosa      Iris-setosa
# 117   Iris-virginica   Iris-virginica
# 113   Iris-virginica   Iris-virginica

# %%
# Predicting the class of a sample
# 's' is sample for which we want to predict its class
s = np.array([5.8, 3.5, 2.4, 1.50], ndmin = 2)
iris_classifier.predict(s)
# Out:
# array(['Iris-versicolor'], dtype=object)

# %%
# Visualizing the decision tree graphically
plt.figure(figsize= (15, 15))
cols=list(X.columns.values)
tree.plot_tree(iris_classifier, filled= True, rounded= True, feature_names=cols)
# Out:
# [Text(334.8, 733.86, 'PetalWidthCm <= 0.8\nentropy = 1.583\nsamples = 112\nvalue = [38, 39, 35]'),
#  Text(251.10000000000002, 570.78, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(418.5, 570.78, 'PetalWidthCm <= 1.75\nentropy = 0.998\nsamples = 74\nvalue = [0, 39, 35]'),
#  Text(167.4, 407.70000000000005, 'PetalLengthCm <= 5.05\nentropy = 0.378\nsamples = 41\nvalue = [0, 38, 3]'),
#  Text(83.7, 244.62, 'entropy = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(251.10000000000002, 244.62, 'SepalLengthCm <= 6.05\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(167.4, 81.54000000000008, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(334.8, 81.54000000000008, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(669.6, 407.70000000000005, 'PetalLengthCm <= 4.85\nentropy = 0.196\nsamples = 33\nvalue = [0, 1, 32]'),
#  Text(585.9, 244.62, 'SepalLengthCm <= 5.95\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(502.20000000000005, 81.54000000000008, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(669.6, 81.54000000000008, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(753.3000000000001, 244.62, 'entropy = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]
